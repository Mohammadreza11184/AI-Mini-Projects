# %%
import cv2
import os
import numpy as np

# %%
files = os.listdir('1')
img = cv2.imread("1/1 (12).jpg")

# %%
cv2.imshow('ax',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('1/1 (1).jpg' )
img2 = cv2.resize(img,(8,32))
img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
img4 = img3.flatten()

# %%
img4.shape
# Out:
# (256,)

# %%
files = os.listdir('1')
x = np.empty((0,256))
y = np.array([])
for filename in files:
    img = cv2.imread('1/' + filename)
    img2 = cv2.resize(img,(8,32))
    img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
    img4 = img3.flatten()
    x = np.append(x,[img4],axis=0)  
    y = np.append(y,1)

files2 = os.listdir('2')


for filename in files2:
    img = cv2.imread('2/' + filename)
    img2 = cv2.resize(img,(8,32))
    img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
    img4 = img3.flatten()
    x = np.append(x,[img4],axis=0)  
    y = np.append(y,2)

files3 = os.listdir('3')


for filename in files3:
    img = cv2.imread('3/' + filename)
    img2 = cv2.resize(img,(8,32))
    img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
    img4 = img3.flatten()
    x = np.append(x,[img4],axis=0)  
    y = np.append(y,3)

files4 = os.listdir('4')


for filename in files4:
    img = cv2.imread('4/' + filename)
    img2 = cv2.resize(img,(8,32))
    img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
    img4 = img3.flatten()
    x = np.append(x,[img4],axis=0)  
    y = np.append(y,4)

files5 = os.listdir('5')


for filename in files5:
    img = cv2.imread('5/' + filename)
    img2 = cv2.resize(img,(8,32))
    img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
    img4 = img3.flatten()
    x = np.append(x,[img4],axis=0)  
    y = np.append(y,5)

files6 = os.listdir('6')


for filename in files6:
    img = cv2.imread('6/' + filename)
    img2 = cv2.resize(img,(8,32))
    img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
    img4 = img3.flatten()
    x = np.append(x,[img4],axis=0)  
    y = np.append(y,6)

files7 = os.listdir('7')


for filename in files7:
    img = cv2.imread('7/' + filename)
    img2 = cv2.resize(img,(8,32))
    img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
    img4 = img3.flatten()
    x = np.append(x,[img4],axis=0)  
    y = np.append(y,7)


files8 = os.listdir('8')


for filename in files8:
    img = cv2.imread('8/' + filename)
    img2 = cv2.resize(img,(8,32))
    img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
    img4 = img3.flatten()
    x = np.append(x,[img4],axis=0)  
    y = np.append(y,8)

files9 = os.listdir('9')


for filename in files9:
    img = cv2.imread('9/' + filename)
    img2 = cv2.resize(img,(8,32))
    img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
    img4 = img3.flatten()
    x = np.append(x,[img4],axis=0)  
    y = np.append(y,9)

# %%
x.shape
# Out:
# (3101, 256)

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x , y , test_size=0.2)

# %%
model = linear_model.LogisticRegression()

# %%
model.fit(X_train,y_train)
out = model.predict(X_test)

# %%
out

# %%
y_test

# %%
x1 = np.empty((0,256))
img = cv2.imread('4/4 (111).jpg')
imgx = cv2.imshow('ax',img)
img2 = cv2.resize(img,(8,32))
img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
img4 = img3.flatten()
x1 = np.append(x1,[img4],axis=0)

# %%
natijeh = model.predict(x1)

# %%
natijeh
# Out:
# array([3.])
