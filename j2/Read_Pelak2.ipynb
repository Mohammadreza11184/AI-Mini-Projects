# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
x = np.empty((0,256))
y  = np.array([])
for k in range(1,10):
    file = os.listdir(str(k))
    for filename in file:
        img = cv2.imread(str(k) + '/' + filename)
        ret,img2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
        img2 = cv2.resize(img,(8,32))
        img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
        img4 = img3.flatten()
        x = np.append(x,[img4],axis=0)
        y = np.append(y,k)

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
model = linear_model.LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# c:\Users\ragab\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
out = model.predict(X_test)

# %%
y_test
# Out:
# array([6., 9., 3., 6., 7., 1., 4., 3., 8., 5., 7., 7., 9., 1., 6., 3., 9.,
#        6., 6., 2., 8., 5., 3., 1., 5., 3., 4., 9., 5., 3., 5., 1., 3., 9.,
#        2., 3., 8., 7., 6., 9., 9., 1., 8., 2., 7., 7., 1., 3., 5., 1., 6.,
#        7., 8., 5., 3., 8., 6., 5., 8., 7., 3., 7., 1., 8., 5., 8., 9., 6.,
#        6., 5., 8., 8., 9., 3., 8., 7., 6., 8., 9., 6., 1., 8., 8., 4., 5.,
#        6., 7., 4., 8., 3., 9., 1., 8., 9., 4., 3., 2., 4., 1., 8., 7., 7.,
#        9., 7., 7., 9., 1., 2., 9., 5., 1., 7., 9., 2., 2., 9., 2., 6., 5.,
#        1., 7., 2., 7., 6., 8., 9., 5., 8., 8., 1., 1., 1., 4., 8., 1., 8.,
#        2., 5., 8., 9., 5., 8., 5., 5., 2., 2., 1., 8., 8., 7., 9., 2., 6.,
#        8., 1., 7., 6., 8., 2., 5., 3., 4., 2., 4., 3., 2., 5., 1., 5., 7.,
#        1., 8., 1., 8., 2., 8., 2., 5., 1., 2., 4., 5., 6., 7., 4., 7., 9.,
#        9., 2., 9., 6., 7., 4., 7., 9., 5., 2., 7., 5., 2., 9., 2., 1., 9.,
# ...

# %%
out
# Out:
# array([6., 9., 2., 6., 7., 1., 4., 3., 8., 5., 7., 7., 9., 1., 6., 3., 9.,
#        6., 6., 2., 8., 5., 3., 1., 5., 3., 4., 9., 5., 3., 5., 1., 4., 2.,
#        2., 3., 8., 7., 6., 9., 9., 1., 8., 2., 7., 7., 1., 3., 5., 1., 2.,
#        7., 8., 5., 3., 8., 4., 5., 8., 7., 3., 7., 1., 8., 5., 8., 9., 6.,
#        6., 5., 8., 8., 9., 3., 8., 7., 6., 8., 9., 7., 1., 7., 8., 4., 5.,
#        5., 7., 9., 8., 9., 9., 1., 8., 9., 4., 3., 2., 4., 1., 8., 7., 7.,
#        9., 7., 7., 9., 1., 2., 9., 5., 1., 7., 9., 2., 2., 9., 3., 6., 5.,
#        1., 7., 2., 7., 6., 8., 9., 8., 8., 8., 1., 1., 1., 4., 8., 1., 8.,
#        2., 5., 8., 9., 5., 8., 5., 5., 2., 3., 1., 8., 8., 7., 9., 5., 6.,
#        8., 1., 7., 9., 8., 2., 5., 3., 4., 2., 4., 3., 2., 5., 1., 5., 1.,
#        1., 8., 1., 8., 2., 8., 2., 5., 1., 2., 4., 5., 6., 7., 7., 7., 9.,
#        9., 2., 9., 6., 7., 4., 7., 9., 5., 2., 7., 5., 2., 9., 2., 1., 1.,
# ...

# %%
img_pelok = cv2.imread("peloke.png")

# %%
img_pelok0 = cv2.imread("peloke.png",0)

# %%
cv2.imshow('ax',img_pelok0)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_pelok0[0]
# Out:
# array([239, 240, 239, 240, 240, 241, 242, 241, 241, 241, 240, 240, 240,
#        239, 240, 240, 240, 240, 241, 240, 240, 241, 242, 240, 240, 240,
#        239, 240, 240, 239, 239, 240, 240, 240, 240, 240, 240, 240, 239,
#        241, 242, 242, 239, 240, 241, 241, 240, 241, 240, 240, 240, 240,
#        240, 241, 242, 242, 242, 241, 240, 240, 240, 240, 239, 239, 240,
#        239, 239, 241, 241, 241, 241, 240, 240, 240, 241, 242, 242, 242,
#        239, 238, 238, 239, 240, 240, 240, 240, 241, 239, 240, 241, 241,
#        239, 240, 239, 239, 240, 240, 240, 241, 241, 241, 241, 241, 241,
#        241, 241, 240, 240, 240, 241, 241, 239, 239, 238, 239, 240, 241,
#        240, 241, 241, 240, 239, 240, 240, 240, 240, 240, 240, 240, 240,
#        240, 240, 240, 240, 240, 240, 239, 240, 241, 241, 240, 239, 239,
#        240, 239, 238, 239, 239, 240, 240, 240, 240, 241, 240, 240, 239,
#        238, 239, 240, 240, 240, 240, 240, 239, 240, 240, 241, 241, 241,
# ...

# %%
img_pelok = cv2.resize(img_pelok,(411,90))

# %%
img_pelok0 = cv2.resize(img_pelok0,(411,90))

# %%
s = 90 - np.sum(img_pelok0,axis=0,keepdims=True)/255

# %%
plt.close()
plt.plot(s[0])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
img_pelok.shape
# Out:
# (90, 411, 3)

# %%
pelok = img_pelok.copy()

pelok = cv2.line(pelok,(277,0),(277,90),(0,0,255),1)
cv2.imshow('ax',pelok)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = img_pelok[:,:50] 
cv2.imshow('ax',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_pelok = cv2.imread("peloke.png")
pelok = img_pelok.copy()
ret,img_pelok = cv2.threshold(img_pelok,127,255,cv2.THRESH_BINARY)
xi = 0
flag1 = False
flag2 =False
xi1 = 0
xi2 = 0
out1 =[]
for i in s[0]:
    xi = xi+ +1

    if i > 9 and flag1 == True and flag2 == False:
           flag2 = True  
           
    
    if i < 5:
       pelok = cv2.line(pelok,(xi,0),(xi,90),(0,0,255),1)     


       if flag1 == False:
           xi1 = xi 

       if flag2  == True:
            xi2 = xi
            flag2 = False
            img1 = img_pelok[:,xi1:xi2] 

            x1 = np.empty((0,256))
            img2 = cv2.resize(img1,(8,32))
            img3 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
            img4 = img3.flatten()
            x1 = np.append(x1,[img4],axis=0)
            natijeh = model.predict(x1)
            out1.append(natijeh[0])
            cv2.imshow('ax',img1)
            cv2.waitKey(0)
            cv2.destroyAllWindows()
             
            
            xi1 = xi2
            
    flag1 = True    

cv2.imshow('ax',pelok)
cv2.waitKey(0)
cv2.destroyAllWindows()   
print(out1)
# Out:
# [5.0, 2.0, 7.0, 8.0, 5.0, 5.0, 8.0, 5.0, 7.0, 4.0, 5.0, 3.0]
